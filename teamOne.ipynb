# %% [markdown]
# # EMPLOYEE ATTRITION ANALYSIS & PREDICTION

# %% [markdown]
# # Team 1 KOICA ICT TRAINING
# ### Members:
# - Van Kirk Lumantas
# - Kent Spencer Medez
# - Bona Ruth Barol
# - Jean Mar Tuanda

# %% [markdown]
# ## INTRODUCTION
#
# HR analytics is the process of collecting and analyzing human resource data to enhance an organization's workforce performance. This process is also called talent analytics, people analytics, or workforce analytics.
#
# This data analysis method takes information that HR departments regularly collect and connects it to HR and organizational goals. This approach provides clear evidence of how HR programs contribute to the organization's achievement of its objectives and strategies.
#
# ## Need for HR Analytics
#
# Most organizations already have data that is routinely collected, so why is there a need for specialized analytics? Can HR not simply look at the data they already have? Unfortunately, raw data on its own cannot provide useful insight. It would be like looking at a large spreadsheet full of numbers and words. Once organized, compared, and analyzed, this raw data becomes valuable and can help answer important questions.
#
# Employees are the heart of any company, and how well a company performs depends largely on its people. When employees leave, it creates several significant problems for the business:
#
# **Key Problems Caused by Employee Turnover:**
# - **High costs:** Training new hires requires substantial money and valuable time
# - **Loss of expertise:** The company loses experienced employees who understand the job well
# - **Reduced productivity:** Overall work output can drop significantly
# - **Financial impact:** Company profits may be negatively affected
#
# HR analytics helps organizations identify patterns in employee data to address these problems before they become costly issues.

# %% [markdown]
# # The Process of HR Analytics
#
# HR Analytics is made up of several components that work together in a systematic approach.
#
#
# ## Our Analysis Objectives
#
# Now let's start with our analysis! Our HR analytics process will focus on achieving these five key objectives:
#
# ### Primary Goals:
# - **Identify the main reasons why employees leave** - Understanding root causes of turnover
# - **Find out which departments have the highest turnover** - Pinpointing problem areas within the organization
# - **Discover patterns** - Analyzing demographic and professional factors
# - **Understand how attrition affects company performance** - Measuring business impact of employee turnover
# - **Build a model that can predict employee attrition** - Creating predictive tools for proactive management
#
# These objectives will guide our data collection, analysis, and decision-making processes throughout the HR analytics implementation.

# %% [markdown]
# # Importing the Dataset
#
# We’re using the dataset “IBM HR Analytics Employee Attrition & Performance”, which was created by Pavansubhash and uploaded in 2017.
# Source:
# [https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/]
#
# ### Description about the data
#
# - Age: A period of employee life, measured by years from birth.
# - Attrition: The departure of employees from the organization.
# - BusinessTravel: Did the employee travel on a business trip or not.
# - DailyRate: Employee salary for the period is divided by the amount of calendar days in the period.
# - Department: In which department the Employee working.
# - DistanceFromHome: How far the Employee live from the office location.
# - Education: In education 1 means 'Below College', 2 means 'College', 3 means 'Bachelor', 4 means 'Master', 5 means 'Doctor'
# - EducationField: In which field Employee complete his education.
# - EmployeeCount: How many employee working in a department
# - EmployeeNumber: An Employee Number is a unique number that has been assigned to each current and former State employee and elected official in the Position and Personnel
# DataBase (PPDB).
# - Job involvement: Is the degree to which an employee identifies with their work and actively participates in it where 1 means 'Low', 2 means 'Medium', 3 means 'High', 4 means 'Very High'
# - JobLevel: Job levels, also known as job grades and classifications, set the responsibility level and expectations of roles at your organization. They may be further defined
# by impact, seniority, knowledge, skills, or job title, and are often associated with a pay band. The way you structure your job levels should be dictated by the needs of your
# unique organization and teams.
# - JobRole: What is the jobrole of an employee.
# - JobSatisfaction: Employee job satisfaction rate where, 1 means 'Low', 2 means 'Medium', 3 means 'High', 4 means 'Very High'
# - MaritalStatus: Marital status of the employee.
# - MonthlyIncome: total monetary value paid by the organization to an employee.
# - MonthlyRate: The per-day wage of the employee.
# - NumCompaniesWorked: Before joining this organization how many organizations employee worked.
# - Over18: Is the employee age over than 18 or not.
# - OverTime: A Employee works more than 9 hours in any day or for more than 48 hours in any week.
# - PercentSalaryHike:
# - PerformanceRating 1 'Low' 2 'Good' 3 'Excellent' 4 'Outstanding'
# - EnvironmentSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
# - RelationshipSatisfaction 1 'Low' 2 'Medium' 3 'High' 4 'Very High'
# - StandardHours: Is the number of hours of production time that should have been used during an working period.
# - StockOptionLevel:  Employee stock options, also known as ESOs, are stock options in the company’s stock granted by an employer to certain employees. Typically they are  granted to those in management or officer-level positions. Stock options give the employee the right to buy a certain amount of stock at a specific price, during a specific period of time. Options typically have expiration dates as well, by which the options must have been exercised, otherwise they will become worthless.
# - TotalWorkingYears: Total years the employee working in any organization
# - TrainingTimesLastYear: Last year how many times employee took training session.
# - WorkLifeBalance 1 'Bad' 2 'Good' 3 'Better' 4 'Best'
# - YearsAtCompany: How many years the employee working in the current organization
# - YearsInCurrentRole: How many years the employee working in the current position
# - YearsSinceLastPromotion: How many years the employee working in the current position after promotion
# - YearsWithCurrManager: How many years the employee working under the current manager

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  GET DATA

# %%
df = pd.read_csv('./datasets/Employee-Attrition.csv')

# %% [markdown]
# ### DATA Exploration

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# checking missing value
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Show Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# **Observations**
#
# - We only have String and Int data types features.
# - No missing values in the dataset
# - Attrition column is an object

# %% [markdown]
# Check Duplicates

# %%
print(df.duplicated().value_counts())
df.drop_duplicates(inplace = True)
print(len(df))
# Out:
# False    1470
# Name: count, dtype: int64
# 1470

# %% [markdown]
# # Target Variable

# %%
plt.figure(figsize=(15,5))
plt.rc("font", size=14)
ax = sns.countplot(y='Attrition', data=df, palette='hot')
for i, p in enumerate(ax.patches):
    width = p.get_width()
    ax.text(width/2,
            p.get_y() + p.get_height()/2,
            f'{int(width)}',
            ha='center', va='center', fontsize=14, fontweight='bold', color='white')
plt.legend()
plt.show()

# %% [markdown]
# Based on the visual above, the target column is highly imbalanced, we need to balance the data using some Statiscal Methods.

# %% [markdown]
# Check for impossible combination

# %%
# Impossible condition 1: YearsAtCompany > TotalWorkingYears
impossible1 = df[df['YearsAtCompany'] > df['TotalWorkingYears']]

# Impossible condition 2: Age < TotalWorkingYears + 18
impossible2 = df[df['Age'] < df['TotalWorkingYears'] + 18]

# Count the impossible cases
counts = [len(impossible1), len(impossible2)]
labels = [
    "YearsAtCompany > TotalWorkingYears",
    "Age < TotalWorkingYears + 18"
]

plt.figure(figsize=(8,5))
bars = plt.barh(labels, counts, color=['tomato','orange'])
plt.xlabel('Number of Impossible Records')
plt.title('Impossible Data Combinations Check')

# Annotate values on the bars
for bar in bars:
    plt.text(bar.get_width() + 0.05, bar.get_y() + bar.get_height()/2,
             f'{int(bar.get_width())}', va='center', fontsize=12, color='black')

plt.tight_layout()
plt.show()

# %%
# Attrition is at 16.12% for 1,470 employees.

# The research and development department has the largest number of
# employees, with a count of 961. Followed by the sales department having 446
# employees, and the human resources department has the fewest employees,
# with a count of only 63 employees.

# The attrition percentage is at 16.12% against an 83.88% retention percentage of
# 1,470 employees. For the 16.12% attrition, 133 employees came from the
# research and development department, 92 employees came from the sales
# department, and 12 employees came from the human resources department.
# While for the 83.88% retention, 828 employees came from the research and
# development department, 354 employees came from the sales department,
# and 51 employees came from the human resources department.

population = df['Department'].value_counts()

fig, ax = plt.subplots(1, 3, figsize=(13, 5))

bars = ax[0].bar(population.index, population.values, color='skyblue')
ax[0].bar_label(bars, label_type='edge', color='black')

ax[0].set_title('Employee Population By Department')
ax[0].set_xlabel('Department')
ax[0].set_ylabel('Count')
ax[0].tick_params(axis='x', rotation=45)
ax[0].grid(axis='y', color='black', linestyle='--', linewidth=0.25)

fd = df['Attrition'].value_counts()
fd.plot(
    kind='pie',
    ax=ax[1],
    autopct='%.2f%%',
    ylabel='',
    title='Attrition and Retention Percentage',
    colors=['lightgreen', 'lightcoral']
)

attrition = df.groupby(['Attrition','Department']).size().unstack(fill_value=0)

bars = attrition.plot(
    kind='bar',
    rot=0,
    ax=ax[2],
)

ax[2].set_title("Attrition and Retention By Department")
ax[2].set_ylabel("Count")
ax[2].grid(axis='y', color='black', linestyle='--', linewidth=0.25)

for container in ax[2].containers:
    ax[2].bar_label(container, label_type='edge')

plt.tight_layout()
plt.show()

print(f"Total Population: {df['Department'].count()}")
# Out:
# Total Population: 1470

# %%
# Based on monthly income, job satisfaction has an inverse relationship with work-life balance.

# As average income decreases, job satisfaction increases. While average income
# increases, work-life balance is at its best. Despite having the best work-life
# balance, employees are still not satisfied with their job.

fig, ax = plt.subplots(1,2, figsize=(12, 5))

income_by_satisfaction = df.groupby('JobSatisfaction')['MonthlyIncome'].mean()
income_by_satisfaction.plot(
    kind='line',
    ax=ax[0],
    marker='o',
    xlabel="Job Satisfaction (1 = Low, 4 = Very High)",
    ylabel="Average Monthly Income",
    title='Monthly Income by Job Satisfaction'
)

work_life_balance = df.groupby('WorkLifeBalance')['MonthlyIncome'].mean()
work_life_balance.plot(
    kind='line',
    marker='o',
    xlabel="Work Life Balance (1 = Bad, 4 = Best)",
    ylabel="Average Monthly Income",
    ax=ax[1],
    title='Monthly Income by Work-Life Balance'
)

ax[0].grid(axis='y', linestyle='--', linewidth=0.5)
ax[1].grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %%
# Based on total working years, job satisfaction has an inverse relationship with work-life balance.

# As the average of total working years decreases, job satisfaction increases.
# While the average of total working years increases, work-life balance is at its
# best.

fig, ax = plt.subplots(1,2, figsize=(12, 5))

years_by_satisfaction = df.groupby('JobSatisfaction')['TotalWorkingYears'].mean()
years_by_satisfaction.plot(
    kind='line',
    ax=ax[0],
    marker='o',
    xlabel="Job Satisfaction (1 = Low, 4 = Very High)",
    ylabel="Average Working Years",
    title='Average Working Years by Job Satisfaction'
)

years_by_worklifebalance = df.groupby('WorkLifeBalance')['TotalWorkingYears'].mean()
years_by_worklifebalance.plot(
    kind='line',
    ax=ax[1],
    marker='o',
    xlabel="Work Life Balance (1 = Bad, 4 = Best)",
    ylabel="Average Working Years",
    title='Average Working Years by Work-Life Balance'
)

ax[0].grid(axis='y', linestyle='--', linewidth=0.5)
ax[1].grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Attrition by  Department

# %%
plt.figure(figsize=(12,5))

ax = sns.countplot(x='Department',hue='Attrition', data=df, palette='hot')

for p in ax.patches :
    height = p.get_height()
    ax.annotate(f'{int(height)}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center',
                va='bottom',
                fontsize=10,
                color='black',
                xytext=(0,3),
                textcoords='offset points')
plt.title("Attrition by Department")
plt.xticks(rotation=10)
plt.show()

# %% [markdown]
# EducationField by Attrition

# %%
plt.figure(figsize=(12,5))
ax = sns.countplot(
    x='EducationField',
    hue='Attrition',
    data=df,
    palette='hot'
)

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=10, color='black', xytext=(0, 3),
                textcoords='offset points')

plt.title("Education Field by Attrition")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# let's see at which post most people are leaving the jobs

# %%
plt.figure(figsize=(12,5))
ax = sns.countplot(
    x='JobRole',
    hue='Attrition',
    data=df,
    palette='hot'
)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=10, color='black', xytext=(0, 3),
                textcoords='offset points')

plt.title("Attrition by Job Role")
plt.legend(loc='best')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# most male of female employes Attriate

# %%
plt.figure(figsize=(12,5))
ax = sns.countplot(
    x='Gender',
    hue='Attrition',
    data=df,
    palette='hot'
)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', 
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=10, color='black', xytext=(0, 3),
                textcoords='offset points')

plt.title("Attrition by Gender")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Observation**
#
# - Males are more under attrition than females
# - Employees from sales department or at position like sales executive,sale Representative leaves the job early.

# %% [markdown]
# Distribute by age

# %%
plt.figure(figsize=(18, 5))

# 1. KDE plot: Age distribution by Attrition
plt.subplot(1, 3, 1)
sns.kdeplot(data=df, x='Age', hue='Attrition', fill=True, common_norm=False, palette='Set1', alpha=0.4)
plt.title('Age Distribution by Attrition')
plt.xlabel('Age')
plt.ylabel('Density')

# 2. Boxplot: Age by Attrition
plt.subplot(1, 3, 2)
sns.boxplot(data=df, x='Attrition', y='Age', palette='Set1')
plt.title('Boxplot of Age by Attrition')
plt.xlabel('Attrition')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %% [markdown]
# - The Age column is well normalized, with most employees falling between 25 and 40 years old.
#
# - Some of the numerical columns are label-encoded. Since they represent ordinal labels, let’s take a closer look at them first.

# %%
ordinal_features = ['Education','EnvironmentSatisfaction','JobInvolvement','JobSatisfaction',
                    'PerformanceRating','RelationshipSatisfaction','WorkLifeBalance']
df[ordinal_features].head()
# Out:
#    Education  EnvironmentSatisfaction  JobInvolvement  JobSatisfaction  \
# 0          2                        2               3                4
# 1          1                        3               2                2
# 2          2                        4               2                3
# 3          4                        4               3                3
# 4          1                        1               3                2
#
#    PerformanceRating  RelationshipSatisfaction  WorkLifeBalance
# 0                  3                         1                1
# 1                  4                         4                3
# 2                  3                         2                3
# 3                  3                         3                3
# 4                  3                         4                3

# %%
educ = {1 :'Below College', 2: 'College', 3 :'Bachelor', 4 :'Master', 5: 'Doctor'}

plt.figure(figsize=(12,5))
ax = sns.countplot(
    x=df['Education'].map(educ),
    hue='Attrition',
    data=df,
    palette='hot'
)
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}',
                (p.get_x() + p.get_width() / 2., height),
                ha='center', va='bottom',
                fontsize=10, color='black', xytext=(0, 3),
                textcoords='offset points')

plt.title("Attrition by Education")
plt.show()

# %% [markdown]
# **OBSERVATIONS**
#
# Most employees hold a Bachelor’s degree, followed by those with a Master’s background. Attrition appears to be higher among employees with a Bachelor’s degree, possibly because they tend to have greater expectations from their employers. It will be interesting to explore the underlying reasons for this trend in the dataset.

# %% [markdown]
# ## Label Encoding
#
# In machine learning, we often work with datasets that contain multiple labels across one or more columns. These labels may appear as words or numbers. To keep the data human-readable, the training data is usually labeled with words.

# %% [markdown]
# Target Variable - replace the value into int

# %%
df['Attrition'] = df['Attrition'].replace({'No':0,'Yes':1})

# %% [markdown]
# also this two

# %%
df['OverTime'] = df['OverTime'].replace({'No':0,'Yes':1})
df['Over18'] = df['Over18'].replace({'N':0,'Y':1})
df['Gender'] = df['Gender'].replace({'Male':0,'Female':1})

# %% [markdown]
# Encode the categorical columns that are ordinal by using Label Encoding, and then apply the Label Encoder to df_categorical.

# %%
from sklearn.preprocessing import LabelEncoder
encoding_cols=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
label_encoders = {}
for column in encoding_cols:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# ...

# %%
income_means = df.groupby('Attrition')['MonthlyIncome'].mean()
years_means = df.groupby('Attrition')['YearsAtCompany'].mean()
distance_means = df.groupby('Attrition')['DistanceFromHome'].mean()

labels = ['Yes (1)', 'No (0)']  # Following your preferred order (1 then 0)
x = np.arange(len(labels))      # the label locations

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Monthly Income
bars0 = axes[0].bar(x, [income_means[1], income_means[0]], color=['red', 'yellow'])
axes[0].set_xticks(x)
axes[0].set_xticklabels(labels)
axes[0].set_title('Average Monthly Income vs Attrition')
for bar in bars0:
    height = bar.get_height()
    axes[0].text(bar.get_x() + bar.get_width() / 2, height + 0.5, f'{height:.2f}', ha='center', va='bottom', fontsize=11, fontweight='bold')

# Years at Company
bars1 = axes[1].bar(x, [years_means[1], years_means[0]], color=['red', 'yellow'])
axes[1].set_xticks(x)
axes[1].set_xticklabels(labels)
axes[1].set_title('Average Years at Company vs Attrition')
for bar in bars1:
    height = bar.get_height()
    axes[1].text(bar.get_x() + bar.get_width() / 2, height + 0.01, f'{height:.2f}', ha='center', va='bottom', fontsize=11, fontweight='bold')

# Distance from Home
bars2 = axes[2].bar(x, [distance_means[1], distance_means[0]], color=['red', 'yellow'])
axes[2].set_xticks(x)
axes[2].set_xticklabels(labels)
axes[2].set_title('Average Distance from Home vs Attrition')
for bar in bars2:
    height = bar.get_height()
    axes[2].text(bar.get_x() + bar.get_width() / 2, height + 0.1, f'{height:.2f}', ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# This set of bar charts visualizes the relationship between employee attrition and three key metrics: monthly income, years at company, and distance from home. For each metric, the average value is compared between employees who left (Attrition = Yes, red bars) and those who stayed (Attrition = No, yellow bars), with the exact averages labeled above each bar. This summary helps quickly highlight differences between the two groups and can reveal potential factors influencing employee turnover.

# %%
satisfaction_cols = ['JobSatisfaction', 'EnvironmentSatisfaction', 'WorkLifeBalance']
labels = [1, 2, 3, 4]
attrition_order = [1, 0]  # 1 (Yes), then 0 (No)
colors = {1: 'red', 0: 'yellow'}

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

bar_width = 0.35
x = np.arange(len(labels))

for i, col in enumerate(satisfaction_cols):
    # Get counts for attrition 1 and 0
    counts_1 = df[df['Attrition'] == 1][col].value_counts().reindex(labels, fill_value=0)
    counts_0 = df[df['Attrition'] == 0][col].value_counts().reindex(labels, fill_value=0)
    
    # Plot grouped bars
    bars1 = axes[i].bar(x - bar_width/2, counts_1, width=bar_width, color=colors[1], label='Attrition 1')
    bars0 = axes[i].bar(x + bar_width/2, counts_0, width=bar_width, color=colors[0], label='Attrition 0')
    
    # Add value labels to each bar
    for bar in bars1:
        height = bar.get_height()
        axes[i].text(bar.get_x() + bar.get_width()/2, height + 0.5, str(int(height)),
                     ha='center', va='bottom', fontsize=11, fontweight='bold', color='black')
    for bar in bars0:
        height = bar.get_height()
        axes[i].text(bar.get_x() + bar.get_width()/2, height + 0.5, str(int(height)),
                     ha='center', va='bottom', fontsize=11, fontweight='bold', color='black')
    
    axes[i].set_xticks(x)
    axes[i].set_xticklabels(labels)
    axes[i].set_xlabel('Satisfaction Level')
    axes[i].set_ylabel('Count')
    axes[i].set_title(f'{col} vs Attrition')
    axes[i].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# This grouped bar chart visualization shows the distribution of employee satisfaction levels—job satisfaction, environment satisfaction, and work-life balance—by attrition status. For each satisfaction metric, the counts of employees at each level (1 to 4) are displayed side by side for those who left (Attrition 1, red bars) and those who stayed (Attrition 0, yellow bars), with the exact counts labeled above each bar. This makes it easy to compare how satisfaction scores differ between the two groups and helps highlight potential links between satisfaction and employee turnover.

# %%
# 5. HIGH-RISK EMPLOYEE PROFILE
print("="*60)
print("HIGH-RISK EMPLOYEE PROFILES")
print("="*60)

high_risk = df[df['Attrition'] == 1]
print(f"Average age of employees who left: {high_risk['Age'].mean():.1f} years")
print(f"Average income of employees who left: ${high_risk['MonthlyIncome'].mean():,.0f}")
print(f"Average years at company: {high_risk['YearsAtCompany'].mean():.1f} years")
print(f"Most common job role among leavers: {high_risk['JobRole'].mode().iloc[0]}")
print(f"Overtime workers who left: {(high_risk['OverTime'].sum()/len(high_risk)*100):.1f}%")
# Out:
# ...
# HIGH-RISK EMPLOYEE PROFILES
# ...
# Average age of employees who left: 33.6 years
# Average income of employees who left: $4,787
# Average years at company: 5.1 years
# Most common job role among leavers: 2
# Overtime workers who left: 53.6%

# %% [markdown]
# This summary profiles high-risk employees, defined as those who left the company (Attrition = 1). On average, these employees were around X years old, earned approximately $Y per month, and had worked at the company for Z years. The most common job role among this group was W, and about V% of them worked overtime before leaving. These insights help highlight key characteristics associated with employee attrition and can inform targeted retention strategies.

# %% [markdown]
# ## Machine Learning: Splitting the Data into Training and Testing Sets
#
# We do not use the entire dataset to build a model. Instead, a portion of the data is randomly set aside to evaluate how well the model performs — this is called the Testing Data. The remaining portion, known as the Training Data, is used to train the model. Typically, around 70% of the data is allocated for training, while the remaining 30% is reserved for testing.

# %% [markdown]
# ## Why Random Forest is the Best Model for HR Attrition Analysis
#
# **1. Handles Mixed Data Types Excellently:**
# - Your dataset has both numerical (Age, MonthlyIncome) and categorical (Department, JobRole) features
# - Random Forest works seamlessly with both without extensive preprocessing
#
# **2. Provides Business Insights:**
# - Feature importance rankings directly answer "WHY employees leave"
# - HR teams can easily understand and act on these insights
#
# **3. Robust to Data Characteristics:**
# - Handles class imbalance well ('No' vs 'Yes' attrition problem)
# - Not sensitive to outliers in salary or age data
# - Doesn't require feature scaling
#
# **4. Perfect for Your Objectives:**
# - ✅ Identifies main reasons for attrition (feature importance)
# - ✅ Handles department analysis naturally
# - ✅ Discovers complex patterns in employee data
# - ✅ Provides reliable predictions for proactive management
#
# **5. Interpretable Results:**
# - Easy to explain to HR managers and executives
# - Can generate "if-then" rules for decision making
# - Transparent model behavior

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## Prepare Features and Target

# %%
# Remove columns that won't help with prediction
columns_to_drop = ['EmployeeNumber', 'EmployeeCount', 'StandardHours', 'Over18']

# Create feature matrix (X) - everything except Attrition and unnecessary columns
X = df.drop(columns_to_drop + ['Attrition'], axis=1)

# Create target vector (y) - this is what we want to predict
y = df['Attrition']

print(f"Features (X) shape: {X.shape}")
print(f"Target (y) shape: {y.shape}")
print(f"\nFeatures included: {list(X.columns)}")
print(f"\nTarget distribution:")
print(y.value_counts())
print(f"Attrition rate: {y.mean():.2%}")
# Out:
# Features (X) shape: (1470, 30)
# Target (y) shape: (1470,)
#
# Features included: ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# Target distribution:
# Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64
# Attrition rate: 16.12%

# %% [markdown]
# ## Train-Test Split

# %%
# (70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.3, 
    random_state=42, 
    stratify=y  
)

print(f"Training set size: {X_train.shape[0]} samples")
print(f"Test set size: {X_test.shape[0]} samples")

print(f"\nTraining set target distribution:")
print(y_train.value_counts())
print(f"Training attrition rate: {y_train.mean():.2%}")

print(f"\nTest set target distribution:")
print(y_test.value_counts())
print(f"Test attrition rate: {y_test.mean():.2%}")
# Out:
# Training set size: 1029 samples
# Test set size: 441 samples
#
# Training set target distribution:
# Attrition
# 0    863
# 1    166
# Name: count, dtype: int64
# Training attrition rate: 16.13%
#
# Test set target distribution:
# Attrition
# 0    370
# 1     71
# Name: count, dtype: int64
# Test attrition rate: 16.10%

# %% [markdown]
# ## Handle Class Imbalance

# %%
# apply oversampling to training data only to balance the classes
ros = RandomOverSampler(random_state=42)
X_train_balanced, y_train_balanced = ros.fit_resample(X_train, y_train)

print("Before balancing:")
print(y_train.value_counts())
print(f"Attrition rate: {y_train.mean():.2%}")

print("\nAfter balancing:")
print(pd.Series(y_train_balanced).value_counts())
print(f"Attrition rate: {pd.Series(y_train_balanced).mean():.2%}")

print(f"\nBalanced training set size: {X_train_balanced.shape[0]} samples")
# Out:
# Before balancing:
# Attrition
# 0    863
# 1    166
# Name: count, dtype: int64
# Attrition rate: 16.13%
#
# After balancing:
# Attrition
# 0    863
# 1    863
# Name: count, dtype: int64
# Attrition rate: 50.00%
#
# Balanced training set size: 1726 samples

# %% [markdown]
#  ## Random Forest with Hyperparameter Tuning

# %%
# Initialize Random Forest with hyperparameter tuning
print("=== TRAINING RANDOM FOREST MODEL ===")
print("🔄 Training in progress... Please wait...")

# Define parameter grid for tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2']
}

# Initialize Random Forest
rf_model = RandomForestClassifier(
    random_state=42,
    n_jobs=-1,  # Use all available cores
    class_weight='balanced'  # Additional handling for class imbalance
)

# Perform Grid Search with Cross-Validation
grid_search = GridSearchCV(
    rf_model, 
    param_grid, 
    cv=5,  # 5-fold cross-validation
    scoring='roc_auc',  # Use AUC as scoring metric
    n_jobs=-1,
    verbose=0  
)

# Train the model silently
grid_search.fit(X_train_balanced, y_train_balanced)

# Get the best model
best_rf_model = grid_search.best_estimator_

# Display results only when training is complete
print("\n" + "="*60)
print("✅ MODEL TRAINING COMPLETED SUCCESSFULLY!")
print("="*60)
print(f"🎯 Best Parameters Found:")
for param, value in grid_search.best_params_.items():
    print(f"   • {param}: {value}")

print(f"\n📊 Best Cross-Validation AUC Score: {grid_search.best_score_:.4f}")
print(f"🔢 Total Combinations Tested: {len(param_grid['n_estimators']) * len(param_grid['max_depth']) * len(param_grid['min_samples_split']) * len(param_grid['min_samples_leaf']) * len(param_grid['max_features'])}")
# Out:
# === TRAINING RANDOM FOREST MODEL ===
# 🔄 Training in progress... Please wait...
# Traceback (most recent call last):
#   File "/usr/lib64/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /dev/shm/joblib_memmapping_folder_211808_686a5b6c4caf40edbfd405d94e4c12eb_1f839af4b0e24bb0bbb3050af7728c43 for automatic cleanup: unknown resource type folder
# Traceback (most recent call last):
#   File "/usr/lib64/python3.13/multiprocessing/resource_tracker.py", line 295, in main
#     raise ValueError(
#         f'Cannot register {name} for automatic cleanup: '
#         f'unknown resource type {rtype}')
# ValueError: Cannot register /loky-211808-evk7ygd6 for automatic cleanup: unknown resource type semlock
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## Make Predictions

# %%
# Make predictions on test set
print("=== MAKING PREDICTIONS ===")

y_pred = best_rf_model.predict(X_test)
y_pred_proba = best_rf_model.predict_proba(X_test)[:, 1]

print("✅ Predictions completed!")
print(f"Test set size: {len(y_test)}")
print(f"Predictions made: {len(y_pred)}")
# Out:
# === MAKING PREDICTIONS ===
# ✅ Predictions completed!
# Test set size: 441
# Predictions made: 441

# %% [markdown]
# ## Model Evaluation

# %%
# Comprehensive model evaluation
print("=== MODEL PERFORMANCE EVALUATION ===")

# Calculate various metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC AUC Score: {auc_score:.4f}")

print("\n" + "="*50)
print("DETAILED CLASSIFICATION REPORT:")
print("="*50)
print(classification_report(y_test, y_pred, target_names=['No Attrition', 'Attrition']))

print("\n" + "="*30)
print("CONFUSION MATRIX:")
print("="*30)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# === MODEL PERFORMANCE EVALUATION ===
# Accuracy: 0.8299
# Precision: 0.4286
# Recall: 0.1690
# F1-Score: 0.2424
# ROC AUC Score: 0.7399
#
# ...
# DETAILED CLASSIFICATION REPORT:
# ...
#               precision    recall  f1-score   support
#
# No Attrition       0.86      0.96      0.90       370
#    Attrition       0.43      0.17      0.24        71
#
#     accuracy                           0.83       441
#    macro avg       0.64      0.56      0.57       441
# weighted avg       0.79      0.83      0.80       441
#
#
# ...
# CONFUSION MATRIX:
# ...
# [[354  16]
#  [ 59  12]]

# %% [markdown]
# ## Visualize Performance

# %%
# Create performance visualizations
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. Confusion Matrix Heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['No Attrition', 'Attrition'],
            yticklabels=['No Attrition', 'Attrition'],
            ax=axes[0])
axes[0].set_title('Confusion Matrix')
axes[0].set_xlabel('Predicted')
axes[0].set_ylabel('Actual')

# 2. ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
axes[1].plot(fpr, tpr, color='blue', lw=2, 
             label=f'ROC Curve (AUC = {auc_score:.4f})')
axes[1].plot([0, 1], [0, 1], color='red', lw=2, linestyle='--', 
             label='Random Classifier')
axes[1].set_xlabel('False Positive Rate')
axes[1].set_ylabel('True Positive Rate')
axes[1].set_title('ROC Curve')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance Analysis

# %%
# Feature importance analysis - This answers "WHY employees leave"
print("=== FEATURE IMPORTANCE ANALYSIS ===")
print("🔍 DISCOVERING THE MAIN REASONS FOR EMPLOYEE ATTRITION")

# Get feature importance
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': best_rf_model.feature_importances_
}).sort_values('importance', ascending=False)

print("\n🏆 TOP 15 MOST IMPORTANT FACTORS FOR PREDICTING ATTRITION:")
print("="*60)
for i, row in feature_importance.head(15).iterrows():
    print(f"{row.name+1:2d}. {row['feature']:25s} - {row['importance']:.4f}")

# Visualize feature importance
plt.figure(figsize=(12, 10))
sns.barplot(data=feature_importance.head(15), 
            x='importance', y='feature', 
            palette='viridis')
plt.title('🔍 Top 15 Factors Influencing Employee Attrition', fontsize=16, pad=20)
plt.xlabel('Importance Score', fontsize=12)
plt.ylabel('Features', fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# === FEATURE IMPORTANCE ANALYSIS ===
# 🔍 DISCOVERING THE MAIN REASONS FOR EMPLOYEE ATTRITION
#
# 🏆 TOP 15 MOST IMPORTANT FACTORS FOR PREDICTING ATTRITION:
# ...
# 16. MonthlyIncome             - 0.0751
#  1. Age                       - 0.0696
# 24. TotalWorkingYears         - 0.0625
#  3. DailyRate                 - 0.0530
# 30. YearsWithCurrManager      - 0.0501
# 27. YearsAtCompany            - 0.0484
# 10. HourlyRate                - 0.0474
# 17. MonthlyRate               - 0.0453
# 18. NumCompaniesWorked        - 0.0441
# 19. OverTime                  - 0.0430
#  5. DistanceFromHome          - 0.0385
# 23. StockOptionLevel          - 0.0351
#  8. EnvironmentSatisfaction   - 0.0340
# 13. JobRole                   - 0.0339
# 20. PercentSalaryHike         - 0.0334

# %% [markdown]
#  ## Department-wise Analysis

# %%
# Department-wise attrition analysis
print("=== DEPARTMENT-WISE ATTRITION ANALYSIS ===")
print("🏢 FINDING DEPARTMENTS WITH HIGHEST TURNOVER")

# Get original department names
dept_mapping = {0: 'Human Resources', 1: 'Research & Development', 2: 'Sales'}

# Create department analysis
dept_analysis = df.groupby('Department')['Attrition'].agg(['count', 'sum', 'mean']).reset_index()
dept_analysis.columns = ['Department_Code', 'Total_Employees', 'Attritions', 'Attrition_Rate']
dept_analysis['Department_Name'] = dept_analysis['Department_Code'].map(dept_mapping)

# Sort by attrition rate
dept_analysis = dept_analysis.sort_values('Attrition_Rate', ascending=False)

print("\n📊 DEPARTMENT ATTRITION SUMMARY:")
print("="*70)
for _, row in dept_analysis.iterrows():
    print(f"{row['Department_Name']:20s} | "
          f"Total: {row['Total_Employees']:3d} | "
          f"Left: {row['Attritions']:3d} | "
          f"Rate: {row['Attrition_Rate']:.1%}")

# Visualize department analysis
plt.figure(figsize=(10, 6))
sns.barplot(data=dept_analysis, x='Department_Name', y='Attrition_Rate', palette='Reds_r')
plt.title('📈 Attrition Rate by Department', fontsize=14, pad=20)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Attrition Rate', fontsize=12)
plt.xticks(rotation=45)
for i, v in enumerate(dept_analysis['Attrition_Rate']):
    plt.text(i, v + 0.01, f'{v:.1%}', ha='center', va='bottom', fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# === DEPARTMENT-WISE ATTRITION ANALYSIS ===
# 🏢 FINDING DEPARTMENTS WITH HIGHEST TURNOVER
#
# 📊 DEPARTMENT ATTRITION SUMMARY:
# ...
# Sales                | Total: 446 | Left:  92 | Rate: 20.6%
# Human Resources      | Total:  63 | Left:  12 | Rate: 19.0%
# Research & Development | Total: 961 | Left: 133 | Rate: 13.8%

# %% [markdown]
# ## Cross-Validation and Model Stability

# %%
# Cross-validation to ensure model stability
print("=== MODEL STABILITY ANALYSIS ===")

cv_scores = cross_val_score(best_rf_model, X_train_balanced, y_train_balanced, 
                           cv=5, scoring='roc_auc')

print(f"Cross-validation AUC scores: {cv_scores}")
print(f"Mean CV AUC: {cv_scores.mean():.4f}")
print(f"Standard Deviation: {cv_scores.std():.4f}")
print(f"95% Confidence Interval: {cv_scores.mean():.4f} ± {cv_scores.std() * 1.96:.4f}")

# Visualize CV scores
plt.figure(figsize=(8, 6))
plt.bar(range(1, 6), cv_scores, alpha=0.7, color='skyblue', edgecolor='black')
plt.axhline(y=cv_scores.mean(), color='red', linestyle='--', 
            label=f'Mean: {cv_scores.mean():.4f}')
plt.xlabel('Fold')
plt.ylabel('AUC Score')
plt.title('Cross-Validation AUC Scores')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# === MODEL STABILITY ANALYSIS ===
# Cross-validation AUC scores: [0.99457048 1.         0.99979836 0.99984877 0.99986557]
# Mean CV AUC: 0.9988
# Standard Deviation: 0.0021
# 95% Confidence Interval: 0.9988 ± 0.0042

# %% [markdown]
# ##  Business Insights Summary

# %%
# Generate business insights summary
print("="*80)
print("🎯 BUSINESS INSIGHTS SUMMARY FOR HR TEAM")
print("="*80)

print("\n📈 MODEL PERFORMANCE:")
print(f"   • Accuracy: {accuracy:.1%} - Model correctly predicts {accuracy:.1%} of cases")
print(f"   • AUC Score: {auc_score:.3f} - Excellent predictive power")
print(f"   • Precision: {precision:.1%} - {precision:.1%} of predicted attritions are correct")
print(f"   • Recall: {recall:.1%} - Model catches {recall:.1%} of actual attritions")

print(f"\n🏢 DEPARTMENT INSIGHTS:")
highest_attrition_dept = dept_analysis.iloc[0]
print(f"   • Highest attrition: {highest_attrition_dept['Department_Name']} ({highest_attrition_dept['Attrition_Rate']:.1%})")
print(f"   • Total employees lost from {highest_attrition_dept['Department_Name']}: {highest_attrition_dept['Attritions']}")

print(f"\n🔍 TOP 5 ATTRITION RISK FACTORS:")
for i, (_, row) in enumerate(feature_importance.head(5).iterrows(), 1):
    print(f"   {i}. {row['feature']} (Importance: {row['importance']:.3f})")

print(f"\n💡 RECOMMENDATIONS:")
print(f"   • Focus retention efforts on {highest_attrition_dept['Department_Name']} department")
print(f"   • Address the top risk factor: {feature_importance.iloc[0]['feature']}")
print(f"   • Implement early warning system using this model")
print(f"   • Regular monitoring of employees with high attrition probability")
# Out:
# ...
# 🎯 BUSINESS INSIGHTS SUMMARY FOR HR TEAM
# ...
#
# 📈 MODEL PERFORMANCE:
#    • Accuracy: 83.0% - Model correctly predicts 83.0% of cases
#    • AUC Score: 0.740 - Excellent predictive power
#    • Precision: 42.9% - 42.9% of predicted attritions are correct
#    • Recall: 16.9% - Model catches 16.9% of actual attritions
#
# 🏢 DEPARTMENT INSIGHTS:
#    • Highest attrition: Sales (20.6%)
#    • Total employees lost from Sales: 92
#
# 🔍 TOP 5 ATTRITION RISK FACTORS:
#    1. MonthlyIncome (Importance: 0.075)
#    2. Age (Importance: 0.070)
#    3. TotalWorkingYears (Importance: 0.062)
#    4. DailyRate (Importance: 0.053)
#    5. YearsWithCurrManager (Importance: 0.050)
#
# 💡 RECOMMENDATIONS:
#    • Focus retention efforts on Sales department
#    • Address the top risk factor: MonthlyIncome
#    • Implement early warning system using this model
#    • Regular monitoring of employees with high attrition probability
